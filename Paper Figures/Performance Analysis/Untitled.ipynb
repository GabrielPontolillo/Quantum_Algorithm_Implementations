# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(19, 12), dpi=100)

import pandas as pd

df = pd.read_excel ('QPEDataClean.xlsx')
df
# Out:
#    Qiskit  Cirq  Q# loop in Q#  Q# no Postpro  Q# with Postpro
# 0     113   130          32650          32967            41814
# 1     108   131          32788          33243            36811
# 2     102   140          33351          32969            34006
# 3     105   137          33415          33137            34279
# 4     106   126          33588          33582            33690
# 5     106   132          32950          32914            36302
# 6     103   132          33088          32237            36416
# 7     102   131          32785          32700            34511
# 8     102   126          33101          32851            33723
# 9     102   128          33468          32171            38010

# %%
fig, ax = plt.subplots()
ax.set_title('Basic Plot')
ax.set_yscale('log')
ax.boxplot(df)
fig.savefig('boxplot.png')
plt.gcf().set_size_inches(20, 20)
